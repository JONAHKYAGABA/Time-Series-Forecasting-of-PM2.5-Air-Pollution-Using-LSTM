# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ###DATA ANALYSIS & MODEL

# %% [markdown]
# ######TANZANIA TIME SERIES GRAPHS

# %%
import pandas as pd
kisumu = pd.read_csv('/content/drive/MyDrive/STATION/kisumu63708_2022.csv')
kisumu
# Out:
#                   Date    TC   TdC    Hr    ddd  ffkmh       P0hPa    Precmm  \
# 0     31/12/2022 18:00  22.6  17.2  72.0  270.0    9.3  885.100000  0.000000
# 1     31/12/2022 12:00  29.0  13.5  39.0  225.0   14.8  883.600000  0.000000
# 2     31/12/2022 09:00  27.0  12.9  42.0  202.5   11.1  886.500000  2.499579
# 3     31/12/2022 06:00  22.3  12.8  55.0   90.0   14.8  888.000000  0.000000
# 4     31/12/2022 03:00  17.8  14.0  78.0   67.5    5.6  886.800000  2.499579
# ...                ...   ...   ...   ...    ...    ...         ...       ...
# 2705  01/01/2022 12:00  27.6  17.9  55.0  247.5   22.2  883.591213  0.000000
# 2706  01/01/2022 09:00  24.8  17.2  63.0  270.0   11.1  883.591213  2.499579
# 2707  01/01/2022 06:00  22.3  16.7  71.0    0.0    3.7  883.591213  3.000000
# 2708  01/01/2022 03:00  17.3  16.2  93.0  360.0    7.4  883.591213  2.499579
# 2709  01/01/2022 00:00  18.0  16.0  88.0  112.5    5.6  883.591213  3.000000
#
# ...

# %%
import pandas as pd
musoma = pd.read_csv('/content/drive/MyDrive/STATION/musoma63733_all_angles.csv')
musoma
# Out:
#                   Date    TC   TdC    Hr    ddd  ffkmh  P0hPa  Precmm  \
# 0     31/12/2022 21:00  21.1  18.3  84.0    0.0    0.0  888.0     0.0
# 1     31/12/2022 18:00  22.6  18.1  76.0    0.0    0.0  886.9     0.0
# 2     31/12/2022 15:00  25.2  17.8  64.0  337.5   18.5  885.1     0.0
# 3     31/12/2022 12:00  26.0  18.6  64.0  315.0   22.2  886.0     0.0
# 4     31/12/2022 09:00  26.7  13.5  44.0  292.5   11.1  888.3     0.0
# ...                ...   ...   ...   ...    ...    ...    ...     ...
# 8073  01/01/2020 12:00  27.6  19.6  62.0  292.5   18.5  883.9     0.0
# 8074  01/01/2020 09:00  27.0  18.4  59.0   67.5    9.3  886.4     0.0
# 8075  01/01/2020 06:00  24.0  19.7  77.0    0.0    0.0  887.6     0.0
# 8076  01/01/2020 03:00  20.9  19.6  92.0    0.0    0.0  885.8     0.0
# 8077  01/01/2020 00:00  22.0  20.0  88.0    0.0    0.0  884.9     0.0
#
#       Prechrs   Nt   Nh  HKm  Viskm  Prec_rate  Classification
# 0           3  2.0  1.0  0.6   30.0        0.0               2
# ...

# %%
import pandas as pd
mwanza = pd.read_csv('/content/drive/MyDrive/STATION/mwanza63756_all_angles.csv')
mwanza
# Out:
#                   Date    TC   TdC    Hr    ddd  ffkmh  P0hPa  Precmm  \
# 0     31/12/2022 18:00  21.8  17.4  76.0    0.0    0.0  886.2     0.0
# 1     31/12/2022 15:00  27.4  16.0  50.0   67.5    9.3  884.5     0.0
# 2     31/12/2022 12:00  28.5  16.1  47.0   67.5   18.5  885.9     0.0
# 3     31/12/2022 09:00  27.1  14.7  47.0   90.0   27.8  887.9     0.0
# 4     31/12/2022 06:00  23.6  15.3  60.0  112.5   18.5  889.1     0.0
# ...                ...   ...   ...   ...    ...    ...    ...     ...
# 8187  01/01/2020 12:00  28.7  18.5  54.0   22.5   16.7  884.5     0.0
# 8188  01/01/2020 09:00  28.4  18.9  56.0    0.0    0.0  886.7     0.0
# 8189  01/01/2020 06:00  23.6  20.5  83.0    0.0    0.0  887.8     1.0
# 8190  01/01/2020 03:00  20.0  18.2  89.0    0.0    0.0  885.9     0.0
# 8191  01/01/2020 00:00  19.5  18.3  93.0    0.0    0.0  886.7     0.0
#
#       Prechrs   Nt   Nh  HKm  Viskm  Prec_rate  Classification
# 0          12  2.0  2.0  0.6   30.0   0.000000               2
# ...

# %%
combined_tanzania_data = pd.concat([kisumu, musoma, mwanza], ignore_index=True)
combined_tanzania_data
# Out:
#                    Date    TC   TdC    Hr    ddd  ffkmh  P0hPa    Precmm  \
# 0      31/12/2022 18:00  22.6  17.2  72.0  270.0    9.3  885.1  0.000000
# 1      31/12/2022 12:00  29.0  13.5  39.0  225.0   14.8  883.6  0.000000
# 2      31/12/2022 09:00  27.0  12.9  42.0  202.5   11.1  886.5  2.499579
# 3      31/12/2022 06:00  22.3  12.8  55.0   90.0   14.8  888.0  0.000000
# 4      31/12/2022 03:00  17.8  14.0  78.0   67.5    5.6  886.8  2.499579
# ...                 ...   ...   ...   ...    ...    ...    ...       ...
# 18975  01/01/2020 12:00  28.7  18.5  54.0   22.5   16.7  884.5  0.000000
# 18976  01/01/2020 09:00  28.4  18.9  56.0    0.0    0.0  886.7  0.000000
# 18977  01/01/2020 06:00  23.6  20.5  83.0    0.0    0.0  887.8  1.000000
# 18978  01/01/2020 03:00  20.0  18.2  89.0    0.0    0.0  885.9  0.000000
# 18979  01/01/2020 00:00  19.5  18.3  93.0    0.0    0.0  886.7  0.000000
#
#        Prechrs   Nt   Nh       HKm  Viskm  Prec_rate  Classification
# ...

# %%
combined_tanzania_data['ddd'] = pd.to_numeric(combined_tanzania_data['ddd'], errors='coerce')
combined_tanzania_data
# Out:
#                    Date    TC   TdC    Hr    ddd  ffkmh  P0hPa    Precmm  \
# 0      31/12/2022 18:00  22.6  17.2  72.0  270.0    9.3  885.1  0.000000
# 1      31/12/2022 12:00  29.0  13.5  39.0  225.0   14.8  883.6  0.000000
# 2      31/12/2022 09:00  27.0  12.9  42.0  202.5   11.1  886.5  2.499579
# 3      31/12/2022 06:00  22.3  12.8  55.0   90.0   14.8  888.0  0.000000
# 4      31/12/2022 03:00  17.8  14.0  78.0   67.5    5.6  886.8  2.499579
# ...                 ...   ...   ...   ...    ...    ...    ...       ...
# 18975  01/01/2020 12:00  28.7  18.5  54.0   22.5   16.7  884.5  0.000000
# 18976  01/01/2020 09:00  28.4  18.9  56.0    0.0    0.0  886.7  0.000000
# 18977  01/01/2020 06:00  23.6  20.5  83.0    0.0    0.0  887.8  1.000000
# 18978  01/01/2020 03:00  20.0  18.2  89.0    0.0    0.0  885.9  0.000000
# 18979  01/01/2020 00:00  19.5  18.3  93.0    0.0    0.0  886.7  0.000000
#
#        Prechrs   Nt   Nh       HKm  Viskm  Prec_rate  Classification
# ...

# %%
combined_tanzania_data = combined_tanzania_data.drop('P0hPa', axis=1)

combined_tanzania_data
# Out:
#                    Date    TC   TdC    Hr    ddd  ffkmh    Precmm  Prechrs  \
# 0      31/12/2022 18:00  22.6  17.2  72.0  270.0    9.3  0.000000       12
# 1      31/12/2022 12:00  29.0  13.5  39.0  225.0   14.8  0.000000        6
# 2      31/12/2022 09:00  27.0  12.9  42.0  202.5   11.1  2.499579        3
# 3      31/12/2022 06:00  22.3  12.8  55.0   90.0   14.8  0.000000        1
# 4      31/12/2022 03:00  17.8  14.0  78.0   67.5    5.6  2.499579        3
# ...                 ...   ...   ...   ...    ...    ...       ...      ...
# 18975  01/01/2020 12:00  28.7  18.5  54.0   22.5   16.7  0.000000        6
# 18976  01/01/2020 09:00  28.4  18.9  56.0    0.0    0.0  0.000000        3
# 18977  01/01/2020 06:00  23.6  20.5  83.0    0.0    0.0  1.000000       24
# 18978  01/01/2020 03:00  20.0  18.2  89.0    0.0    0.0  0.000000        3
# 18979  01/01/2020 00:00  19.5  18.3  93.0    0.0    0.0  0.000000        6
#
#         Nt   Nh       HKm  Viskm  Prec_rate  Classification
# ...

# %%
combined_tanzania_data.describe()
# Out:
#                  TC           TdC            Hr          ddd         ffkmh  \
# count  18980.000000  18980.000000  18980.000000  18980.00000  18980.000000
# mean      23.110762     17.537121     72.607753    118.05000      9.614492
# std        3.420472      2.482421     15.033814    129.29892     15.446875
# min      -81.200000    -80.400000      4.000000      0.00000      0.000000
# 25%       20.600000     16.600000     62.000000      0.00000      0.000000
# 50%       22.800000     18.000000     74.000000     90.00000      9.300000
# 75%       25.800000     19.100000     85.000000    247.50000     18.500000
# max       34.700000     29.200000    175.000000    360.00000    691.600000
#
#              Precmm       Prechrs            Nt            Nh           HKm  \
# count  18980.000000  18980.000000  18975.000000  18980.000000  18980.000000
# mean       1.244595      7.723656      3.799144      1.712516      0.583165
# ...

# %%
import matplotlib.pyplot as plt
new_combined_tanzania_data= combined_tanzania_data[['Date', 'Classification']]
combined_tanzania_data=new_combined_tanzania_data
combined_tanzania_data['Date'] = pd.to_datetime(combined_tanzania_data['Date'])

# Sort the DataFrame by the 'Date' column
combined_tanzania_data = combined_tanzania_data.sort_values(by='Date')

# Remove duplicates based on the 'Date' column
combined_tanzania_data = combined_tanzania_data.drop_duplicates(subset=['Date'])

# Set the 'Date' column as the index (required for time series analysis)
combined_tanzania_data.set_index('Date', inplace=True)

# Plot the time series analysis curve with a red line connecting points
plt.figure(figsize=(12, 6))
plt.plot(combined_tanzania_data.index, combined_tanzania_data['Classification'], linestyle='-', color='red')
plt.title('Time Series Analysis of Classification')
plt.xlabel('Date')
plt.ylabel('Classification')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-9-355ffad62a80>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_tanzania_data['Date'] = pd.to_datetime(combined_tanzania_data['Date'])

# %%
import matplotlib.pyplot as plt


# Convert the 'Date' column to a datetime object if it's not already in the correct format
new_combined_tanzania_data['Date'] = pd.to_datetime(new_combined_tanzania_data['Date'])

# Sort the DataFrame by the 'Date' column
new_combined_tanzania_data = new_combined_tanzania_data.sort_values(by='Date')

# Remove duplicates based on the 'Date' column
new_combined_tanzania_data = new_combined_tanzania_data.drop_duplicates(subset=['Date'])

# Set the 'Date' column as the index (required for time series analysis)
new_combined_tanzania_data.set_index('Date', inplace=True)

# Plot the time series analysis as a scatter plot
plt.figure(figsize=(12, 6))
plt.scatter(new_combined_tanzania_data.index, new_combined_tanzania_data['Classification'], marker='o', color='red', label='Data Points')
plt.title('Scatter Plot of Classification Over Time')
plt.xlabel('Date')
plt.ylabel('Classification')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# <ipython-input-10-c6ef98176e60>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_combined_tanzania_data['Date'] = pd.to_datetime(new_combined_tanzania_data['Date'])

# %% [markdown]
# ######UGANDAN DATA TIME SERIES GRAPHS

# %%
import pandas as pd
entebbe = pd.read_csv('/content/drive/MyDrive/STATION/entebbe63602.csv')
entebbe
# Out:
#                   Date    TC   TdC    Hr ddd  ffkmh  P0hPa  Precmm  Prechrs  \
# 0     30/12/2020 18:00  24.4  18.2  68.0  12   13.0  883.1    0.00       12
# 1     30/12/2020 15:00  26.3  19.0  64.0   9   22.2  881.9    0.00        3
# 2     30/12/2020 12:00  27.7  20.7  66.0   7   14.8  882.9    0.00        6
# 3     30/12/2020 09:00  27.4  20.8  67.0   7   14.8  885.0    0.00        3
# 4     30/12/2020 06:00  22.3  21.5  95.0   1    5.6  885.5    0.01       24
# ...                ...   ...   ...   ...  ..    ...    ...     ...      ...
# 2922  01/01/2022 21:00  22.1  18.9  82.0  12    9.3  885.9    0.00        3
# 2923  01/01/2022 18:00  21.4  18.4  83.0  13    5.6  885.9    0.00       12
# 2924  01/01/2022 12:00  24.2  18.2  69.0   6    9.3  885.7    0.00        6
# 2925  01/01/2022 09:00  22.8  18.2  75.0  14   18.5  887.0    0.00        3
# 2926  01/01/2022 06:00  20.2  18.2  88.0   6   18.5  888.5    2.00       24
#
#        Nt   Nh  HKm  Viskm  Prec_rate  Classification
# ...

# %%
entebbe = entebbe.drop("P0hPa", axis=1)
entebbe
# Out:
#                   Date    TC   TdC    Hr ddd  ffkmh  Precmm  Prechrs   Nt  \
# 0     30/12/2020 18:00  24.4  18.2  68.0  12   13.0    0.00       12  2.0
# 1     30/12/2020 15:00  26.3  19.0  64.0   9   22.2    0.00        3  2.0
# 2     30/12/2020 12:00  27.7  20.7  66.0   7   14.8    0.00        6  3.0
# 3     30/12/2020 09:00  27.4  20.8  67.0   7   14.8    0.00        3  2.0
# 4     30/12/2020 06:00  22.3  21.5  95.0   1    5.6    0.01       24  3.0
# ...                ...   ...   ...   ...  ..    ...     ...      ...  ...
# 2922  01/01/2022 21:00  22.1  18.9  82.0  12    9.3    0.00        3  5.0
# 2923  01/01/2022 18:00  21.4  18.4  83.0  13    5.6    0.00       12  4.0
# 2924  01/01/2022 12:00  24.2  18.2  69.0   6    9.3    0.00        6  8.0
# 2925  01/01/2022 09:00  22.8  18.2  75.0  14   18.5    0.00        3  6.0
# 2926  01/01/2022 06:00  20.2  18.2  88.0   6   18.5    2.00       24  7.0
#
#        Nh  HKm  Viskm  Prec_rate  Classification
# ...

# %%
import pandas as pd
jinja = pd.read_csv('/content/drive/MyDrive/STATION/jinja63682.csv')
jinja
# Out:
#                   Date    TC   TdC    Hr  ddd  ffkmh  P0hPa  Precmm  Prechrs  \
# 0     31/12/2020 15:00  23.0  19.7  82.0    6   11.1  881.8     0.0        3
# 1     31/12/2020 06:00  21.0  19.5  91.0   16    5.6  883.6     0.0       24
# 2     30/12/2020 12:00  29.0  16.7  47.0    8    9.3  880.4     0.0        6
# 3     30/12/2020 06:00  25.0  20.7  77.0    8    7.4  883.4     0.0       24
# 4     29/12/2020 12:00  29.2  14.8  41.0   10    7.4  880.4     0.0        6
# ...                ...   ...   ...   ...  ...    ...    ...     ...      ...
# 2151  04/01/2022 06:00  21.0  19.5  91.0   15    7.4  885.7     0.0       24
# 2152  02/01/2022 15:00  25.2  18.9  68.0    9   11.1  880.2     0.0        3
# 2153  01/01/2022 12:00  25.0  17.7  64.0    8   11.1  883.6     0.0        6
# 2154  01/01/2022 09:00  24.5  17.6  65.0    8    9.3  886.1     0.0        3
# 2155  01/01/2022 06:00  19.5  18.0  91.0    0    0.0  886.1    59.0       24
#
# ...

# %%
jinja = jinja.drop("P0hPa", axis=1)
jinja
# Out:
#                   Date    TC   TdC    Hr  ddd  ffkmh  Precmm  Prechrs   Nt  \
# 0     31/12/2020 15:00  23.0  19.7  82.0    6   11.1     0.0        3  7.0
# 1     31/12/2020 06:00  21.0  19.5  91.0   16    5.6     0.0       24  7.0
# 2     30/12/2020 12:00  29.0  16.7  47.0    8    9.3     0.0        6  5.0
# 3     30/12/2020 06:00  25.0  20.7  77.0    8    7.4     0.0       24  5.0
# 4     29/12/2020 12:00  29.2  14.8  41.0   10    7.4     0.0        6  2.0
# ...                ...   ...   ...   ...  ...    ...     ...      ...  ...
# 2151  04/01/2022 06:00  21.0  19.5  91.0   15    7.4     0.0       24  7.0
# 2152  02/01/2022 15:00  25.2  18.9  68.0    9   11.1     0.0        3  3.0
# 2153  01/01/2022 12:00  25.0  17.7  64.0    8   11.1     0.0        6  6.0
# 2154  01/01/2022 09:00  24.5  17.6  65.0    8    9.3     0.0        3  7.0
# 2155  01/01/2022 06:00  19.5  18.0  91.0    0    0.0    59.0       24  7.0
#
#        Nh  HKm  Viskm  Prec_rate  Classification
# ...

# %%
import pandas as pd
kampala = pd.read_csv('/content/drive/MyDrive/STATION/kampala63680.csv')
kampala
# Out:
#                   Date    TC   TdC    Hr  ddd  ffkmh  Precmm  Prechrs  Nt  \
# 0     30/12/2020 15:00  27.0  18.0  58.0    0    0.0     0.0        3   2
# 1     30/12/2020 12:00  25.0  18.0  65.0   13   13.0     0.0        6   2
# 2     30/12/2020 09:00  27.5  19.3  61.0   13    5.6     0.0        3   4
# 3     30/12/2020 06:00  22.4  19.6  84.0    0    0.0     0.1       24   2
# 4     29/12/2020 12:00  27.5  17.8  55.0    0    0.0     0.0        6   4
# ...                ...   ...   ...   ...  ...    ...     ...      ...  ..
# 2074  05/01/2022 06:00  25.5  16.1  56.0   13    7.4     0.0       24   7
# 2075  04/01/2022 12:00  26.0  14.8  50.0    9    7.4     0.0        6   6
# 2076  01/01/2022 12:00  25.0  17.5  63.0    9    7.4     0.0        6   4
# 2077  01/01/2022 09:00  21.5  17.8  79.0    9   11.1     0.0        3   8
# 2078  01/01/2022 06:00  19.6  19.0  96.0    8   14.4     2.0       24   8
#
#        Nh  HKm  Viskm  Prec_rate  Classification
# ...

# %%
combined_uganda_data = pd.concat([entebbe, jinja, kampala], ignore_index=True)
combined_uganda_data
# Out:
#                   Date    TC   TdC    Hr ddd  ffkmh  Precmm  Prechrs   Nt  \
# 0     30/12/2020 18:00  24.4  18.2  68.0  12   13.0    0.00       12  2.0
# 1     30/12/2020 15:00  26.3  19.0  64.0   9   22.2    0.00        3  2.0
# 2     30/12/2020 12:00  27.7  20.7  66.0   7   14.8    0.00        6  3.0
# 3     30/12/2020 09:00  27.4  20.8  67.0   7   14.8    0.00        3  2.0
# 4     30/12/2020 06:00  22.3  21.5  95.0   1    5.6    0.01       24  3.0
# ...                ...   ...   ...   ...  ..    ...     ...      ...  ...
# 7157  05/01/2022 06:00  25.5  16.1  56.0  13    7.4    0.00       24  7.0
# 7158  04/01/2022 12:00  26.0  14.8  50.0   9    7.4    0.00        6  6.0
# 7159  01/01/2022 12:00  25.0  17.5  63.0   9    7.4    0.00        6  4.0
# 7160  01/01/2022 09:00  21.5  17.8  79.0   9   11.1    0.00        3  8.0
# 7161  01/01/2022 06:00  19.6  19.0  96.0   8   14.4    2.00       24  8.0
#
#        Nh  HKm  Viskm  Prec_rate  Classification
# ...

# %%
combined_uganda_data['ddd'] = pd.to_numeric(combined_uganda_data['ddd'], errors='coerce')
combined_uganda_data
# Out:
#                   Date    TC   TdC    Hr   ddd  ffkmh  Precmm  Prechrs   Nt  \
# 0     30/12/2020 18:00  24.4  18.2  68.0  12.0   13.0    0.00       12  2.0
# 1     30/12/2020 15:00  26.3  19.0  64.0   9.0   22.2    0.00        3  2.0
# 2     30/12/2020 12:00  27.7  20.7  66.0   7.0   14.8    0.00        6  3.0
# 3     30/12/2020 09:00  27.4  20.8  67.0   7.0   14.8    0.00        3  2.0
# 4     30/12/2020 06:00  22.3  21.5  95.0   1.0    5.6    0.01       24  3.0
# ...                ...   ...   ...   ...   ...    ...     ...      ...  ...
# 7157  05/01/2022 06:00  25.5  16.1  56.0  13.0    7.4    0.00       24  7.0
# 7158  04/01/2022 12:00  26.0  14.8  50.0   9.0    7.4    0.00        6  6.0
# 7159  01/01/2022 12:00  25.0  17.5  63.0   9.0    7.4    0.00        6  4.0
# 7160  01/01/2022 09:00  21.5  17.8  79.0   9.0   11.1    0.00        3  8.0
# 7161  01/01/2022 06:00  19.6  19.0  96.0   8.0   14.4    2.00       24  8.0
#
#        Nh  HKm  Viskm  Prec_rate  Classification
# ...

# %%
entebbe = entebbe [['Date', 'Classification']]

# %%
entebbe
# Out:
#                   Date  Classification
# 0     30/12/2020 18:00               2
# 1     30/12/2020 15:00               2
# 2     30/12/2020 12:00               2
# 3     30/12/2020 09:00               2
# 4     30/12/2020 06:00               2
# ...                ...             ...
# 2922  01/01/2022 21:00               2
# 2923  01/01/2022 18:00               2
# 2924  01/01/2022 12:00               2
# 2925  01/01/2022 09:00               2
# 2926  01/01/2022 06:00               2
#
# [2927 rows x 2 columns]

# %%
new_combined_uganda_data = combined_uganda_data[['Date', 'Classification']]
combined_uganda_data=new_combined_uganda_data

# %%
import matplotlib.pyplot as plt

combined_uganda_data['Date'] = pd.to_datetime(combined_uganda_data['Date'])

# Sort the DataFrame by the 'Date' column
combined_uganda_data = combined_uganda_data.sort_values(by='Date')

# Remove duplicates based on the 'Date' column
combined_uganda_data = combined_uganda_data.drop_duplicates(subset=['Date'])

# Set the 'Date' column as the index (required for time series analysis)
combined_uganda_data.set_index('Date', inplace=True)

# Plot the time series analysis curve with a line connecting points
plt.figure(figsize=(12, 6))
plt.plot(combined_uganda_data.index, combined_uganda_data['Classification'], linestyle='-')
plt.title('Time Series Analysis of Classification')
plt.xlabel('Date')
plt.ylabel('Classification')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-21-a900044ed845>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_uganda_data['Date'] = pd.to_datetime(combined_uganda_data['Date'])

# %%
import matplotlib.pyplot as plt

combined_uganda_data=new_combined_uganda_data
combined_uganda_data['Date'] = pd.to_datetime(combined_uganda_data['Date'])

# Sort the DataFrame by the 'Date' column
combined_uganda_data = combined_uganda_data.sort_values(by='Date')

# Set the 'Date' column as the index (required for time series analysis)
combined_uganda_data.set_index('Date', inplace=True)

# Plot the time series analysis curve with a line connecting points
plt.figure(figsize=(12, 6))
plt.plot(combined_uganda_data.index, combined_uganda_data['Classification'], linestyle='-')
plt.title('Time Series Analysis of Classification')
plt.xlabel('Date')
plt.ylabel('Classification')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-22-33aea884f858>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_uganda_data['Date'] = pd.to_datetime(combined_uganda_data['Date'])

# %%
import matplotlib.pyplot as plt

combined_uganda_data = new_combined_uganda_data
combined_uganda_data['Date'] = pd.to_datetime(combined_uganda_data['Date'])

# Sort the DataFrame by the 'Date' column
combined_uganda_data = combined_uganda_data.sort_values(by='Date')

# Set the 'Date' column as the index (required for time series analysis)
combined_uganda_data.set_index('Date', inplace=True)

# Plot the time series analysis as a scatter plot
plt.figure(figsize=(12, 6))
plt.scatter(combined_uganda_data.index, combined_uganda_data['Classification'], marker='o', color='blue', label='Data Points')
plt.title('Scatter Plot of Classification Over Time')
plt.xlabel('Date')
plt.ylabel('Classification')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# <ipython-input-23-bcae268b19de>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_uganda_data['Date'] = pd.to_datetime(combined_uganda_data['Date'])

# %% [markdown]
# ######Dickey-Fuller Test for Stationarity

# %%
import pandas as pd
from statsmodels.tsa.stattools import adfuller
import numpy as np

# Assuming 'combined_uganda_data' is your DataFrame
combined_uganda_data = new_combined_uganda_data
combined_uganda_data.loc[:, 'Date'] = pd.to_datetime(combined_uganda_data['Date'])

# Convert the 'Date' column to a datetime object if it's not already in the correct format
combined_uganda_data['Date'] = pd.to_datetime(combined_uganda_data['Date'])

# Sort the DataFrame by the 'Date' column
combined_uganda_data = combined_uganda_data.sort_values(by='Date')

# Remove duplicates based on the 'Date' column
combined_uganda_data = combined_uganda_data.drop_duplicates(subset=['Date'])

# Set the 'Date' column as the index (required for time series analysis)
combined_uganda_data.set_index('Date', inplace=True)

# Check for and handle missing or infinite values in the original data
if combined_uganda_data['Classification'].isnull().values.any() or not np.isfinite(combined_uganda_data['Classification']).all():
    print('Original data contains missing or infinite values. Please handle this issue before proceeding.')
else:
    # Define a function to perform the Dickey-Fuller test
    def adf_test(timeseries):
        result = adfuller(timeseries, autolag='AIC')
        print('ADF Statistic:', result[0])
        print('p-value:', result[1])
        print('Critical Values:', result[4])
        if result[1] <= 0.05:
            print('Data is stationary')
        else:
            print('Data is non-stationary')

    # Perform the Dickey-Fuller test on the original 'Classification' data
    print('Dickey-Fuller Test for Original Data (Classification):')
    adf_test(combined_uganda_data['Classification'])

    # If the 'Classification' data is non-stationary, you can apply differencing to make it stationary
    # Example: Take the first difference
    combined_uganda_data['First Difference'] = combined_uganda_data['Classification'] - combined_uganda_data['Classification'].shift(1)

    # Check for and handle missing or infinite values in the differenced data
    if combined_uganda_data['First Difference'].isnull().values.any() or not np.isfinite(combined_uganda_data['First Difference']).all():
        print('Differenced data contains missing or infinite values. Please handle this issue before proceeding.')
    else:
        # Perform the Dickey-Fuller test on the differenced 'Classification' data
        print('Dickey-Fuller Test for First Difference (Classification):')
        adf_test(combined_uganda_data['First Difference'])
# Out:
# Dickey-Fuller Test for Original Data (Classification):
# ADF Statistic: -21.44513366033956
# p-value: 0.0
# Critical Values: {'1%': -3.431979353761444, '5%': -2.8622599593539513, '10%': -2.567153241895466}
# Data is stationary
# Differenced data contains missing or infinite values. Please handle this issue before proceeding.
# <ipython-input-24-aca55d1b69d6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_uganda_data.loc[:, 'Date'] = pd.to_datetime(combined_uganda_data['Date'])
# ...

# %% [markdown]
# ##### LSTM MODEL

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam

# Assuming combined_df has been loaded and contains columns: 'time', 'input_voltage', 'el_power'

# Data preparation: Selecting 'time' and 'input_voltage' as features to predict 'el_power'
X = combined_df[['time', 'input_voltage']].values
y = combined_df['el_power'].values

# Scaling the data
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.reshape(-1, 1))

# Create sequences for LSTM
def create_sequences(X, y, seq_length=10):
    X_seq, y_seq = [], []
    for i in range(len(X) - seq_length):
        X_seq.append(X[i:i+seq_length])
        y_seq.append(y[i+seq_length])
    return np.array(X_seq), np.array(y_seq)

seq_length = 10
X_seq, y_seq = create_sequences(X_scaled, y_scaled, seq_length)

# Split data into training and test sets
split_ratio = 0.8
split = int(len(X_seq) * split_ratio)

X_train, X_test = X_seq[:split], X_seq[split:]
y_train, y_test = y_seq[:split], y_seq[split:]

# Build LSTM model for multivariate input
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1))
model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# Train model
model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test), verbose=1)

# Predict and evaluate
y_pred = model.predict(X_test)
y_test_inverse = scaler_y.inverse_transform(y_test)
y_pred_inverse = scaler_y.inverse_transform(y_pred)

# Calculate evaluation metrics
mse = mean_squared_error(y_test_inverse, y_pred_inverse)
rmse = np.sqrt(mse)
r2 = r2_score(y_test_inverse, y_pred_inverse)

# Display results
lstm_results = {
    "Time and Input Voltage vs Electric Power (el_power)": {
        "R-squared": r2,
        "Mean Squared Error": mse,
        "Root Mean Squared Error": rmse
    }
}

lstm_results

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import precision_score, recall_score, f1_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical


# Concatenate the dataframes
combined_uganda_data = pd.concat([entebbe, jinja, kampala], ignore_index=True)
combined_uganda_data = combined_uganda_data[['Date', 'Classification']]

# Ensure that 'Date' is in datetime format
combined_uganda_data['Date'] = pd.to_datetime(combined_uganda_data['Date'])

combined_uganda_data = combined_uganda_data.sort_values(by='Date')

# Set 'Date' as the index (required for time series data)
combined_uganda_data.set_index('Date', inplace=True)

# Select the 'Classification' column as your target variable
y = combined_uganda_data['Classification'].values
# Convert target variable to one-hot encoding
y = to_categorical(y, num_classes=3)

# Create sequences for the LSTM model
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length):
        seq = data[i:i + seq_length]
        sequences.append(seq)
    return np.array(sequences)

seq_length = 80  # Adjust the sequence length based on your data
X = create_sequences(y, seq_length)
# Ensure that the feature and target data have the same number of samples
min_samples = min(X.shape[0], y.shape[0])
X = X[:min_samples]
y = y[:min_samples]

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Create and train the LSTM model
model = Sequential()
model.add(LSTM(100, activation='tanh', input_shape=(seq_length, 3)))
model.add(Dense(3, activation='softmax'))
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=60, validation_data=(X_test, y_test))

# Plot training history
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training History')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Evaluate the model on the test set
y_pred = model.predict(X_test)
# Convert the predicted probabilities to class labels
y_pred_labels = np.argmax(y_pred, axis=1)
y_test_labels = np.argmax(y_test, axis=1)

f1 = f1_score(y_test_labels, y_pred_labels, average='weighted')
print(f"F1 Score: {f1}")
# Precision
precision = precision_score(y_test_labels, y_pred_labels, average='weighted')
print(f"Precision: {precision}")

# Recall
recall = recall_score(y_test_labels, y_pred_labels, average='weighted')
print(f"Recall: {recall}")
# Create the confusion matrix
conf_matrix = confusion_matrix(y_test_labels, y_pred_labels)
# Display the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)
# Visualize the confusion matrix using seaborn
class_names = ['Class 0', 'Class 1', 'Class 2']
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Save the trained model
model.save('/content/drive/MyDrive/STATION/LSTM_MODEL.h5')
# Out:
# Epoch 1/60
# 178/178 [==============================] - 3s 9ms/step - loss: 0.6486 - accuracy: 0.6886 - val_loss: 0.6182 - val_accuracy: 0.7128
# Epoch 2/60
# 178/178 [==============================] - 1s 6ms/step - loss: 0.6318 - accuracy: 0.6886 - val_loss: 0.6092 - val_accuracy: 0.7128
# Epoch 3/60
# 178/178 [==============================] - 1s 6ms/step - loss: 0.6316 - accuracy: 0.6886 - val_loss: 0.6098 - val_accuracy: 0.7128
# Epoch 4/60
# 178/178 [==============================] - 1s 6ms/step - loss: 0.6300 - accuracy: 0.6886 - val_loss: 0.6096 - val_accuracy: 0.7128
# Epoch 5/60
# 178/178 [==============================] - 1s 6ms/step - loss: 0.6322 - accuracy: 0.6886 - val_loss: 0.6170 - val_accuracy: 0.7128
# Epoch 6/60
# 178/178 [==============================] - 1s 6ms/step - loss: 0.6309 - accuracy: 0.6886 - val_loss: 0.6112 - val_accuracy: 0.7128
# Epoch 7/60
# ...

# %%
best_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_1 (LSTM)               (None, 50)                10800
#
#  dense_1 (Dense)             (None, 3)                 153
#
# ...
# Total params: 10953 (42.79 KB)
# Trainable params: 10953 (42.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #####MLP MODEL

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, roc_curve, auc, f1_score, precision_score, recall_score
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical

# Assume 'entebbe', 'jinja', 'kampala', and other necessary variables are defined

combined_uganda_data = pd.concat([entebbe, jinja, kampala], ignore_index=True)
combined_uganda_data = combined_uganda_data[['Date', 'Classification']]

# Ensure that 'Date' is in datetime format
combined_uganda_data['Date'] = pd.to_datetime(combined_uganda_data['Date'])

combined_uganda_data = combined_uganda_data.sort_values(by='Date')

# Set 'Date' as the index (required for time series data)
combined_uganda_data.set_index('Date', inplace=True)

# Select the 'Classification' column as your target variable
y = combined_uganda_data['Classification'].values
# Convert target variable to one-hot encoding
y = to_categorical(y, num_classes=3)

# Create sequences for the ANN model
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length):
        seq = data[i:i + seq_length]
        sequences.append(seq)
    return np.array(sequences)

seq_length = 80
X = create_sequences(y, seq_length)
# Ensure that the feature and target data have the same number of samples
min_samples = min(X.shape[0], y.shape[0])
X = X[:min_samples]
y = y[:min_samples]

# Flatten the sequences
X = X.reshape((X.shape[0], -1))

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

model = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dropout(0.5),  # Add dropout
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dropout(0.5),  # Add dropout
    tf.keras.layers.Dense(3, activation='softmax')
])

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(X_train, y_train, epochs=30, verbose=0,
                    validation_data=(X_test, y_test),
                    callbacks=[early_stopping])

# Plot Training Curves
plt.figure(figsize=(12, 6))

# Plot Training & Validation Accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot Training & Validation Loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()
# Evaluate the model on the test set
y_pred = model.predict(X_test)

# Convert the predicted probabilities to class labels
y_pred_labels = np.argmax(y_pred, axis=1)
y_test_labels = np.argmax(y_test, axis=1)

# F1 Score
f1 = f1_score(y_test_labels, y_pred_labels, average='weighted')
print(f"F1 Score: {f1}")

# Precision
precision = precision_score(y_test_labels, y_pred_labels, average='weighted')
print(f"Precision: {precision}")

# Recall
recall = recall_score(y_test_labels, y_pred_labels, average='weighted')
print(f"Recall: {recall}")

# ROC Curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(3):  # Assuming 3 classes
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC Curves for each class
plt.figure(figsize=(8, 6))
for i in range(3):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for each class')
plt.legend()
plt.show()

# Create the confusion matrix
conf_matrix = confusion_matrix(y_test_labels, y_pred_labels)

# Display the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)

# Visualize the confusion matrix using seaborn
class_names = ['Class 0', 'Class 1', 'Class 2']
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# Save the trained model
model.save('/content/drive/MyDrive/STATION/MLP_MODEL.h5')
# Out:
# 45/45 [==============================] - 0s 1ms/step
# F1 Score: 0.9947103798561243
# Precision: 0.9929558208055997
# Recall: 0.9964714184897672
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Confusion Matrix:
# [[  0   1   4]
#  [  0 416   0]
#  [  0   0 996]]
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ####ANN

# %%
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, roc_curve, auc, f1_score, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical

# Add these imports for visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'entebbe', 'jinja', 'kampala', and other necessary variables are defined

combined_uganda_data = pd.concat([entebbe, jinja, kampala], ignore_index=True)
combined_uganda_data = combined_uganda_data[['Date', 'Classification']]

# Ensure that 'Date' is in datetime format
combined_uganda_data['Date'] = pd.to_datetime(combined_uganda_data['Date'])

# Sort by date
combined_uganda_data = combined_uganda_data.sort_values(by='Date')

# Convert 'Date' to numeric values
combined_uganda_data['Numeric_Date'] = combined_uganda_data['Date'].astype(int)

# Create lag features based on the 'Numeric_Date' column
for i in range(1, 80):  # You can adjust the number of lag features based on your needs
    combined_uganda_data[f'Numeric_Date_Lag_{i}'] = combined_uganda_data['Numeric_Date'].shift(i)

# Drop rows with NaN resulting from lag features creation
combined_uganda_data = combined_uganda_data.dropna()

# Select the 'Classification' column as your target variable
y = combined_uganda_data['Classification'].values

# Convert target variable to one-hot encoding

# Create sequences for the ANN model
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length):
        seq = data[i:i + seq_length]
        sequences.append(seq)
    return np.array(sequences)

seq_length = 80  # Adjust the sequence length based on your data
X = create_sequences(combined_uganda_data.drop(['Date', 'Numeric_Date', 'Classification'], axis=1), seq_length)

# Ensure that the feature and target data have the same number of samples
min_samples = min(X.shape[0], y.shape[0])
X = X[:min_samples]
y = y[:min_samples]

# Flatten the sequences
X = X.reshape((X.shape[0], -1))

# Scale the input features using MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, shuffle=False)



# Define a function to create and compile the model
def create_model(input_shape, learning_rate=0.001):
    model = Sequential([
        Dense(64, activation='relu', input_shape=input_shape),
        Dense(32, activation='relu'),
        Dense(16, activation='relu'),
        Dense(3, activation='softmax')
    ])

    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    return model

# Use EarlyStopping to prevent overfitting and save the best model
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model with a range of hyperparameter values
learning_rates = [0.01, 0.001, 0.0001]
epochs = 30

for lr in learning_rates:
    model = create_model((X_train.shape[1],), learning_rate=lr)

    history = model.fit(X_train, y_train, epochs=epochs, validation_data=(X_test, y_test), callbacks=[early_stopping], verbose=0)

    # Evaluate the model on the test set
    y_pred = model.predict(X_test)
    # F1 Score
    f1 = f1_score(y_test_labels, y_pred_labels, average='weighted')
    print(f"F1 Score for learning rate {lr}: {f1}")

best_learning_rate = 0.001
model = create_model((X_train.shape[1],), learning_rate=best_learning_rate)

history = model.fit(X_train, y_train, epochs=epochs, validation_data=(X_test, y_test), callbacks=[early_stopping])
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot Training & Validation Loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# Evaluate the model on the test set
y_pred = model.predict(X_test)

# Convert the predicted probabilities to class labels
y_pred_labels = np.argmax(y_pred, axis=1)
y_test_labels = np.argmax(y_test, axis=1)

# F1 Score
f1 = f1_score(y_test_labels, y_pred_labels, average='weighted')
print(f"F1 Score: {f1}")

# ROC Curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()

n_classes = 3  # Assuming 3 classes
y_test_categorical = to_categorical(y_test, num_classes=n_classes)

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_categorical[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC Curves for each class
plt.figure(figsize=(8, 6))
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for each class')
plt.legend()
plt.show()


# Visualize the confusion matrix using seaborn
class_names = ['Class 0', 'Class 1', 'Class 2']
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Save the trained model
model.save('/content/drive/MyDrive/STATION/ANN_MODEL.h5')
# Out:
# 44/44 [==============================] - 0s 2ms/step
# F1 Score for learning rate 0.01: 0.5917428216113951
# 44/44 [==============================] - 0s 2ms/step
# F1 Score for learning rate 0.001: 0.5917428216113951
# 44/44 [==============================] - 0s 2ms/step
# F1 Score for learning rate 0.0001: 0.5917428216113951
# Epoch 1/30
# 176/176 [==============================] - 2s 5ms/step - loss: 0.6921 - accuracy: 0.6814 - val_loss: 0.9130 - val_accuracy: 0.7116
# Epoch 2/30
# 176/176 [==============================] - 1s 4ms/step - loss: 0.6653 - accuracy: 0.6881 - val_loss: 0.6290 - val_accuracy: 0.7116
# Epoch 3/30
# 176/176 [==============================] - 1s 4ms/step - loss: 0.6541 - accuracy: 0.6828 - val_loss: 0.6196 - val_accuracy: 0.7116
# Epoch 4/30
# 176/176 [==============================] - 1s 4ms/step - loss: 0.6478 - accuracy: 0.6901 - val_loss: 0.6238 - val_accuracy: 0.7116
# Epoch 5/30
# ...

# %%
from sklearn.metrics import precision_score, recall_score



# Evaluate the model on the test set
y_pred = model.predict(X_test)

# Convert the predicted probabilities to class labels
y_pred_labels = np.argmax(y_pred, axis=1)
y_test_labels = np.argmax(y_test_categorical, axis=1)

# F1 Score
f1 = f1_score(y_test_labels, y_pred_labels, average='weighted')
precision = precision_score(y_test_labels, y_pred_labels, average='weighted')
recall = recall_score(y_test_labels, y_pred_labels, average='weighted')

print(f"F1 Score: {f1}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
# Out:
# F1 Score: 0.6917428216113951
# Precision: 0.6064237281313796
# Recall: 0.8116345467523197

# %% [markdown]
# ###### ARIMA MODEL

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.arima.model import ARIMA
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, roc_curve, auc, f1_score, classification_report

# Assuming 'entebbe', 'jinja', 'kampala', and other necessary variables are defined

combined_uganda_data = pd.concat([entebbe, jinja, kampala], ignore_index=True)
combined_uganda_data = combined_uganda_data[['Date', 'Classification']]

# Ensure that 'Date' is in datetime format
combined_uganda_data['Date'] = pd.to_datetime(combined_uganda_data['Date'])

# Sort by date
combined_uganda_data = combined_uganda_data.sort_values(by='Date')

# Convert 'Date' to numeric values
combined_uganda_data['Numeric_Date'] = combined_uganda_data['Date'].astype(int)

# Create lag features based on the 'Numeric_Date' column
for i in range(1, 80):  # You can adjust the number of lag features based on your needs
    combined_uganda_data[f'Numeric_Date_Lag_{i}'] = combined_uganda_data['Numeric_Date'].shift(i)

# Drop rows with NaN resulting from lag features creation
combined_uganda_data = combined_uganda_data.dropna()

# Forecast using ARIMA
arima_order = (5, 1, 0)
for i in range(1, 80):
    model = ARIMA(combined_uganda_data['Numeric_Date'], order=arima_order)
    fit_model = model.fit()
    combined_uganda_data[f'ARIMA_Forecast_{i}'] = fit_model.forecast(steps=1)

# Select the 'Date' as your feature and 'Classification' as your target variable
X = combined_uganda_data['Date']
y = combined_uganda_data['Classification'].values

# Convert target variable to one-hot encoding

# Create sequences for the ANN model
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length):
        seq = data[i:i + seq_length]
        sequences.append(seq)
    return np.array(sequences)

seq_length = 80  # Adjust the sequence length based on your data
X = create_sequences(X, seq_length)

# Ensure that the feature and target data have the same number of samples
min_samples = min(X.shape[0], y.shape[0])
X = X[:min_samples]
y = y[:min_samples]

# Flatten the sequences
X = X.reshape((X.shape[0], -1))

# Scale the input features using MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, shuffle=False)
history = model.fit(X_train, y_train)

# Plot Training Curves
plt.figure(figsize=(12, 6))

# Plot Training & Validation Accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot Training & Validation Loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# Evaluate the model on the test set
y_pred = model.predict(X_test)

# # Convert the predicted probabilities to class labels
# y_pred_labels = np.argmax(y_pred, axis=1)
# y_test_labels = np.argmax(y_test)

# # F1 Score
# f1 = f1_score(y_test_labels, y_pred_labels, average='weighted')
# print(f"F1 Score: {f1}")


# ROC Curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()

n_classes = 3  # Assuming 3 classes
y_test_categorical = to_categorical(y_test, num_classes=n_classes)

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_categorical[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC Curves for each class
plt.figure(figsize=(8, 6))
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for each class')
plt.legend()
plt.show()



# Visualize the confusion matrix using seaborn
class_names = ['Class 0', 'Class 1', 'Class 2']
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# ...

# %%
from sklearn.metrics import precision_score, recall_score
# Evaluate the model on the test set
y_pred = model.predict(X_test)
# Convert the predicted probabilities to class labels
y_pred_labels = np.argmax(y_pred, axis=1)
y_test_labels = np.argmax(y_test_categorical, axis=1)
# F1 Score
f1 = f1_score(y_test_labels, y_pred_labels, average='weighted')
precision = precision_score(y_test_labels, y_pred_labels, average='weighted')
recall = recall_score(y_test_labels, y_pred_labels, average='weighted')

print(f"F1 Score: {f1}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")

# %% [markdown]
# #### DBNS

# %%
# !pip install pyDBN
# Out:
# ERROR: Could not find a version that satisfies the requirement pyDBN (from versions: none)
# ERROR: No matching distribution found for pyDBN

# %%
import numpy as np
import pandas as pd
import pydbn
from pydbn.models import DBN
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from pydbn.model import DBNRegressor

# Assuming combined_df has been loaded and contains columns: 'time', 'input_voltage', 'el_power'

# Data preparation: Selecting 'time' and 'input_voltage' as features to predict 'el_power'
X = combined_df[['time', 'input_voltage']].values
y = combined_df['el_power'].values

# Scaling the data
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.reshape(-1, 1))

# Split data into training and test sets
split_ratio = 0.8
split = int(len(X_scaled) * split_ratio)

X_train, X_test = X_scaled[:split], X_scaled[split:]
y_train, y_test = y_scaled[:split], y_scaled[split:]

# Build and train DBN model for regression
model = DBNRegressor(hidden_layers_structure=[128, 64, 32, 16], learning_rate=0.01, epochs=20)

# Train DBN model
model.fit(X_train, y_train.ravel())

# Predict and evaluate
y_pred = model.predict(X_test)
y_test_inverse = scaler_y.inverse_transform(y_test)
y_pred_inverse = scaler_y.inverse_transform(y_pred.reshape(-1, 1))

# Calculate evaluation metrics
mse = mean_squared_error(y_test_inverse, y_pred_inverse)
rmse = np.sqrt(mse)
r2 = r2_score(y_test_inverse, y_pred_inverse)

# Display results
dbn_results = {
    "Time and Input Voltage vs Electric Power (el_power)": {
        "R-squared": r2,
        "Mean Squared Error": mse,
        "Root Mean Squared Error": rmse
    }
}

dbn_results
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-ea1b6109de5f> in <cell line: 3>()
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import pydbn
#       4 from pydbn.models import DBN
#       5 from sklearn.preprocessing import MinMaxScaler
#
# ModuleNotFoundError: No module named 'pydbn'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ###### CNN MODEL

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, auc, roc_curve
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, roc_curve, auc, f1_score, classification_report,precision_score,recall_score

# Assuming 'entebbe', 'jinja', 'kampala', and other necessary variables are defined

combined_uganda_data = pd.concat([entebbe, jinja, kampala], ignore_index=True)
combined_uganda_data = combined_uganda_data[['Date', 'Classification']]

# Ensure that 'Date' is in datetime format
combined_uganda_data['Date'] = pd.to_datetime(combined_uganda_data['Date'])

# Sort by date
combined_uganda_data = combined_uganda_data.sort_values(by='Date')

# Convert 'Date' to numeric values
combined_uganda_data['Numeric_Date'] = combined_uganda_data['Date'].astype(int)

# Create lag features based on the 'Numeric_Date' column
for i in range(1, 80):  # You can adjust the number of lag features based on your needs
    combined_uganda_data[f'Numeric_Date_Lag_{i}'] = combined_uganda_data['Numeric_Date'].shift(i)

# Drop rows with NaN resulting from lag features creation
combined_uganda_data = combined_uganda_data.dropna()

# Select the 'Date' as your feature and 'Classification' as your target variable
X = combined_uganda_data.drop(['Date', 'Numeric_Date', 'Classification'], axis=1).values
y = combined_uganda_data['Classification'].values

# Convert target variable to one-hot encoding
y = to_categorical(y)
# Reshape the input data for CNN (assuming you have only one feature, adjust accordingly)
X = X.reshape((X.shape[0], X.shape[1], 1))
# Scale the input features using MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X.reshape(X.shape[0], -1)).reshape(X.shape)
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, shuffle=False)
# Define a function to create and compile the CNN model
def model(input_shape, learning_rate=0.01):
    model = Sequential([
        Conv1D(32, kernel_size=3, activation='relu', input_shape=input_shape),
        MaxPooling1D(pool_size=2),
        Flatten(),
        Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        Dense(16, activation='relu'),
        Dense(3, activation='softmax')
    ])

    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# Use EarlyStopping to prevent overfitting and save the best model
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the CNN model
model = model((X_train.shape[1], X_train.shape[2]), learning_rate=0.1)
epochs = 30
# Train the new layers on new data
history = model.fit(X_train, y_train,
                        validation_data=(X_test, y_test ),
                        epochs=30)  # Adjust the number of epochs accordingly
# Plot Training Curves
plt.figure(figsize=(12, 6))

# Plot Training & Validation Accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot Training & Validation Loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# Evaluate the model on the test set
y_pred = model.predict(X_test)

# Convert the predicted probabilities to class labels
y_pred_labels = np.argmax(y_pred, axis=1)
y_test_labels = np.argmax(y_test, axis=1)

# F1 Score
f1 = f1_score(y_test_labels, y_pred_labels, average='weighted')
print(f"F1 Score: {f1}")
# Precision
precision = precision_score(y_test_labels, y_pred_labels, average='weighted')
print(f"Precision: {precision}")

# Recall
recall = recall_score(y_test_labels, y_pred_labels, average='weighted')
print(f"Recall: {recall}")

# ROC Curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(3):  # Assuming 3 classes
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC Curves for each class
plt.figure(figsize=(8, 6))
for i in range(3):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for each class')
plt.legend()
plt.show()

# Create the confusion matrix
conf_matrix = confusion_matrix(y_test_labels, y_pred_labels)

# Display the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)
# Visualize the confusion matrix using seaborn
class_names = ['Class 0', 'Class 1', 'Class 2']
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Epoch 1/30
# 178/178 [==============================] - 2s 5ms/step - loss: 0.6975 - accuracy: 0.6858 - val_loss: 0.6184 - val_accuracy: 0.7114
# Epoch 2/30
# 178/178 [==============================] - 1s 4ms/step - loss: 0.6333 - accuracy: 0.6899 - val_loss: 0.6421 - val_accuracy: 0.7114
# Epoch 3/30
# 178/178 [==============================] - 1s 4ms/step - loss: 0.6329 - accuracy: 0.6899 - val_loss: 0.6103 - val_accuracy: 0.7114
# Epoch 4/30
# 178/178 [==============================] - 1s 4ms/step - loss: 0.6332 - accuracy: 0.6899 - val_loss: 0.6159 - val_accuracy: 0.7114
# Epoch 5/30
# 178/178 [==============================] - 1s 4ms/step - loss: 0.6360 - accuracy: 0.6899 - val_loss: 0.6102 - val_accuracy: 0.7114
# Epoch 6/30
# 178/178 [==============================] - 1s 4ms/step - loss: 0.6323 - accuracy: 0.6899 - val_loss: 0.6121 - val_accuracy: 0.7114
# Epoch 7/30
# ...

# %% [markdown]
# #### TIME SERIES  MODELS WITH FOR TRANSFER LEARNING  TANZANIA

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense
combined_tanzania_data = pd.concat([kisumu,musoma, mwanza], ignore_index=True)
combined_tanzania_data = combined_tanzania_data[['Date', 'Classification']]

# Ensure that 'Date' is in datetime format
combined_tanzania_data['Date'] = pd.to_datetime(combined_tanzania_data['Date'])

combined_tanzania_data = combined_tanzania_data.sort_values(by='Date')

# Set 'Date' as the index (required for time series data)
combined_tanzania_data.set_index('Date', inplace=True)

# Select the 'Classification' column as your target variable
y = combined_tanzania_data['Classification'].values
# Convert target variable to one-hot encoding
y = to_categorical(y, num_classes=3)

# Create sequences for the ANN model
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length):
        seq = data[i:i + seq_length]
        sequences.append(seq)
    return np.array(sequences)

seq_length = 80  # Adjust the sequence length based on your data
X = create_sequences(y, seq_length)
# Ensure that the feature and target data have the same number of samples
min_samples = min(X.shape[0], y.shape[0])
X = X[:min_samples]
y = y[:min_samples]

# Flatten the sequences
X = X.reshape((X.shape[0], -1))

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)


# Load entire model from file
model = tf.keras.models.load_model('/content/drive/MyDrive/STATION/LSTM_MODEL.h5')

# Create a new model with the same architecture as the loaded model
def create_new_model():
    # You need to define the architecture of your original model here

    new_model = tf.keras.Sequential([
        Dense(128, activation='relu', input_shape=(input_shape,)),  # Adjust input_shape accordingly
        Dense(64, activation='relu'),
        # ... Add other layers from your original model
    ])
    return new_model

# Create a new model with the same architecture
new_model = create_new_model()

# Load weights into the new model
new_model.load_weights('/content/drive/MyDrive/STATION/LSTM_MODEL.h5')

# Freezing layers
for layer in new_model.layers[:-2]:
    layer.trainable = False

# Add new top layers
new_model.add(Dense(64, activation='relu'))
new_model.add(Dense(10, activation='softmax'))

# Compile the new model
adam = tf.keras.optimizers.Adam(learning_rate=0.001)  # Adjust learning rate accordingly
new_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the new layers on new data
history = new_model.fit(X_train_new, y_train_new,
                        validation_data=(X_val_new, y_val_new),
                        epochs=30)  # Adjust the number of epochs accordingly
# Plot Training Curves
plt.figure(figsize=(12, 6))

# Plot Training & Validation Accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot Training & Validation Loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# Evaluate the model on the test set
y_pred = model.predict(X_test)

# Convert the predicted probabilities to class labels
y_pred_labels = np.argmax(y_pred, axis=1)
y_test_labels = np.argmax(y_test, axis=1)

# F1 Score
f1 = f1_score(y_test_labels, y_pred_labels, average='weighted')
print(f"F1 Score: {f1}")

# ROC Curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(3):  # Assuming 3 classes
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC Curves for each class
plt.figure(figsize=(8, 6))
for i in range(3):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for each class')
plt.legend()
plt.show()

# Create the confusion matrix
conf_matrix = confusion_matrix(y_test_labels, y_pred_labels)

# Display the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)
# Visualize the confusion matrix using seaborn
class_names = ['Class 0', 'Class 1', 'Class 2']
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 119/119 [==============================] - 0s 2ms/step
# F1 Score: 0.9988119149726168
# Confusion Matrix:
# [[   0    1    2]
#  [   0   28    0]
#  [   0    0 3749]]

# %% [markdown]
# ##### LIMITED DATA CASE KISUMU WITHOUT TRANSFER LEARNING

# %%
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, roc_curve, auc
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import f1_score, classification_report
from tensorflow.keras.utils import to_categorical

# Assuming 'entebbe', 'jinja', 'kampala', and other necessary variables are defined

combined_tanzania_data = pd.concat([kisumu], ignore_index=True)
combined_tanzania_data = combined_tanzania_data[['Date', 'Classification']]

# Ensure that 'Date' is in datetime format
combined_tanzania_data['Date'] = pd.to_datetime(combined_tanzania_data['Date'])

combined_tanzania_data = combined_tanzania_data.sort_values(by='Date')

# Set 'Date' as the index (required for time series data)
combined_tanzania_data.set_index('Date', inplace=True)

# Select the 'Classification' column as your target variable
y = combined_tanzania_data['Classification'].values
# Convert target variable to one-hot encoding
y = to_categorical(y, num_classes=3)


# Create sequences for the ANN model
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length):
        seq = data[i:i + seq_length]
        sequences.append(seq)
    return np.array(sequences)

seq_length = 80  # Adjust the sequence length based on your data
X = create_sequences(y, seq_length)
# Ensure that the feature and target data have the same number of samples
min_samples = min(X.shape[0], y.shape[0])
X = X[:min_samples]
y = y[:min_samples]

# Flatten the sequences
X = X.reshape((X.shape[0], -1))

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

model = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dropout(0.5),  # Add dropout
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dropout(0.5),  # Add dropout
    tf.keras.layers.Dense(3, activation='softmax')
])


# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=30, verbose=0, validation_data=(X_test, y_test))

# Plot Training Curves
plt.figure(figsize=(12, 6))

# Plot Training & Validation Accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot Training & Validation Loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# Evaluate the model on the test set
y_pred = model.predict(X_test)

# Convert the predicted probabilities to class labels
y_pred_labels = np.argmax(y_pred, axis=1)
y_test_labels = np.argmax(y_test, axis=1)

# F1 Score
f1 = f1_score(y_test_labels, y_pred_labels, average='weighted')
print(f"F1 Score: {f1}")
# Precision
precision = precision_score(y_test_labels, y_pred_labels, average='weighted')
print(f"Precision: {precision}")

# Recall
recall = recall_score(y_test_labels, y_pred_labels, average='weighted')
print(f"Recall: {recall}")


# ROC Curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(3):  # Assuming 3 classes
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC Curves for each class
plt.figure(figsize=(8, 6))
for i in range(3):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for each class')
plt.legend()
plt.show()

# Create the confusion matrix
conf_matrix = confusion_matrix(y_test_labels, y_pred_labels)

# Display the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)


# Visualize the confusion matrix using seaborn
class_names = ['Class 0', 'Class 1', 'Class 2']
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Epoch 1/30
# 66/66 [==============================] - 1s 6ms/step - loss: 0.2399 - accuracy: 0.9211 - val_loss: 0.0381 - val_accuracy: 0.9924
# Epoch 2/30
# 66/66 [==============================] - 0s 4ms/step - loss: 0.0366 - accuracy: 0.9938 - val_loss: 0.0296 - val_accuracy: 0.9924
# Epoch 3/30
# 66/66 [==============================] - 0s 4ms/step - loss: 0.0249 - accuracy: 0.9938 - val_loss: 0.0270 - val_accuracy: 0.9924
# Epoch 4/30
# 66/66 [==============================] - 0s 4ms/step - loss: 0.0214 - accuracy: 0.9938 - val_loss: 0.0228 - val_accuracy: 0.9924
# Epoch 5/30
# 66/66 [==============================] - 0s 4ms/step - loss: 0.0121 - accuracy: 0.9938 - val_loss: 0.0204 - val_accuracy: 0.9924
# Epoch 6/30
# 66/66 [==============================] - 0s 4ms/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.0167 - val_accuracy: 0.9962
# Epoch 7/30
# ...

# %% [markdown]
# ##### LIMITED DATA CASE KISUMU WITH TRANSFER LEARNING

# %%
import tensorflow as tf
from sklearn.metrics import precision_score, recall_score, f1_score
from tensorflow.keras.layers import Dense
combined_tanzania_data = pd.concat([kisumu], ignore_index=True)
combined_tanzania_data = combined_tanzania_data[['Date', 'Classification']]

# Ensure that 'Date' is in datetime format
combined_tanzania_data['Date'] = pd.to_datetime(combined_tanzania_data['Date'])

combined_tanzania_data = combined_tanzania_data.sort_values(by='Date')

# Set 'Date' as the index (required for time series data)
combined_tanzania_data.set_index('Date', inplace=True)

# Select the 'Classification' column as your target variable
y = combined_tanzania_data['Classification'].values
# Convert target variable to one-hot encoding
y = to_categorical(y, num_classes=3)

# Create sequences for the ANN model
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length):
        seq = data[i:i + seq_length]
        sequences.append(seq)
    return np.array(sequences)

seq_length = 80  # Adjust the sequence length based on your data
X = create_sequences(y, seq_length)
# Ensure that the feature and target data have the same number of samples
min_samples = min(X.shape[0], y.shape[0])
X = X[:min_samples]
y = y[:min_samples]

# Flatten the sequences
X = X.reshape((X.shape[0], -1))

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)


# Load entire model from file
model = tf.keras.models.load_model('/content/drive/MyDrive/STATION/MLP_MODEL.h5')

# Create a new model with the same architecture as the loaded model
new_model = tf.keras.Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(64, activation='relu'),
    # ... Add other layers from your original model
])

# Load entire model from file
model = tf.keras.models.load_model('/content/drive/MyDrive/STATION/LSTM_MODEL.h5')

# Create a new model with the same architecture as the loaded model up to a certain layer
base_model = tf.keras.Sequential(model.layers[:-2])  # Remove the last two layers

# Add your own top layers
new_top_layers = tf.keras.Sequential([
    Dense(64, activation='relu'),
    Dense(3, activation='softmax')
])

# Combine the base model and new top layers
new_model = tf.keras.Sequential([
    base_model,
    new_top_layers
])

# Load weights into the new model
new_model.load_weights('/content/drive/MyDrive/STATION/LSTM_MODEL.h5', by_name=True)

# Compile the new model
adam = tf.keras.optimizers.Adam(learning_rate=0.001)
new_model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])

# Train the new layers on new data
history = new_model.fit(X_train, y_train,
                        validation_data=(X_test, y_test),
                        epochs=30)
# Plot Training Curves
plt.figure(figsize=(12, 6))

# Plot Training & Validation Accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot Training & Validation Loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# Evaluate the model on the test set
y_pred = model.predict(X_test)

# Convert the predicted probabilities to class labels
y_pred_labels = np.argmax(y_pred, axis=1)
y_test_labels = np.argmax(y_test, axis=1)

# F1 Score
f1 = f1_score(y_test_labels, y_pred_labels, average='weighted')
print(f"F1 Score: {f1}")
# Precision
precision = precision_score(y_test_labels, y_pred_labels, average='weighted')
print(f"Precision: {precision}")

# Recall
recall = recall_score(y_test_labels, y_pred_labels, average='weighted')
print(f"Recall: {recall}")

# ROC Curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(3):  # Assuming 3 classes
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC Curves for each class
plt.figure(figsize=(8, 6))
for i in range(3):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for each class')
plt.legend()
plt.show()

# Create the confusion matrix
conf_matrix = confusion_matrix(y_test_labels, y_pred_labels)

# Display the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)
# Visualize the confusion matrix using seaborn
class_names = ['Class 0', 'Class 1', 'Class 2']
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 17/17 [==============================] - 0s 2ms/step
# F1 Score: 0.9971491986100752
# Precision: 0.9962013536994089
# Recall: 0.9980988593155894
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Confusion Matrix:
# [[  0   0   1]
#  [  0   3   0]
#  [  0   0 522]]
